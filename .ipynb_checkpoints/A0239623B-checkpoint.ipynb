# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading Data

# %%
train = pd.read_csv("Assignment2_train.csv")
test = pd.read_csv("Assignment2_test.csv")

# %%
train.head()
# Out:
#    index  age                 race      sex      education   f1    f2   f3  \
# 0      1   26                White     Male   Some-college  a_2   b_4  c_0
# 1      2   35                White     Male   Some-college  a_2   b_3  c_0
# 2      3   61                White     Male        HS-grad  a_2  b_12  c_0
# 3      4   48   Asian-Pac-Islander   Female      Bachelors  a_5   b_1  c_4
# 4      5   20                White     Male   Some-college  a_4   b_6  c_3
#
#      f4   f5      f6  f7  f8    f9  f10  y
# 0  d_39  e_4   53833  10   0     0   42  0
# 1  d_39  e_4   67728  10   0  2051   45  0
# 2  d_39  e_6  268831   9   0     0   53  0
# 3  d_30  e_4  238360  13   0     0   40  0
# 4  d_39  e_4  199011  10   0     0   12  0

# %%
# drop index column 
train = train.drop(columns=["index"])

# %%
train.head()
# Out:
#    age                 race      sex      education   f1    f2   f3    f4  \
# 0   26                White     Male   Some-college  a_2   b_4  c_0  d_39
# 1   35                White     Male   Some-college  a_2   b_3  c_0  d_39
# 2   61                White     Male        HS-grad  a_2  b_12  c_0  d_39
# 3   48   Asian-Pac-Islander   Female      Bachelors  a_5   b_1  c_4  d_30
# 4   20                White     Male   Some-college  a_4   b_6  c_3  d_39
#
#     f5      f6  f7  f8    f9  f10  y
# 0  e_4   53833  10   0     0   42  0
# 1  e_4   67728  10   0  2051   45  0
# 2  e_6  268831   9   0     0   53  0
# 3  e_4  238360  13   0     0   40  0
# 4  e_4  199011  10   0     0   12  0

# %% [markdown]
# Import Label Encoder - To turn categorical variables into numericals

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
cat_cols = ['race','sex','education','f1','f2','f3','f4','f5']
train[cat_cols] = train[cat_cols].apply(label_encoder.fit_transform)

# %%
train.head()
# Out:
#    age  race  sex  education  f1  f2  f3  f4  f5      f6  f7  f8    f9  f10  y
# 0   26     4    1         15   2   9   0  32   4   53833  10   0     0   42  0
# 1   35     4    1         15   2   8   0  32   4   67728  10   0  2051   45  0
# 2   61     4    1         11   2   4   0  32   6  268831   9   0     0   53  0
# 3   48     1    0          9   5   1   4  23   4  238360  13   0     0   40  0
# 4   20     4    1         15   4  11   3  32   4  199011  10   0     0   12  0

# %%
# target data 
y = train['y']

# features 
x = train.iloc[:,:-1]

# %%
# check for null values 
x.isnull().sum()
# do not have missing values
# Out:
# age          0
# race         0
# sex          0
# education    0
# f1           0
# f2           0
# f3           0
# f4           0
# f5           0
# f6           0
# f7           0
# f8           0
# f9           0
# f10          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
# split dataset into training set and validation set
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.3, random_state=23)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# instantiate log reg model
log_model = LogisticRegression(random_state=101)

# %%
# fit the model with data 
log_model.fit(x_train,y_train)
y_val_logmodel = log_model.predict(x_val)
print("Accuracy:", metrics.accuracy_score(y_val,y_val_logmodel))
print("Recall:", metrics.recall_score(y_val,y_val_logmodel))
print("Precision:", metrics.precision_score(y_val,y_val_logmodel))
print("F1 Score:", metrics.f1_score(y_val,y_val_logmodel))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_val_logmodel,labels=[1,0])
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_val_logmodel))
# Out:
# Accuracy: 0.7920692684151085
# Recall: 0.3037974683544304
# Precision: 0.6308871851040526
# F1 Score: 0.41011035955856184
#
# Confusion Matrix:
#
# [[ 576 1320]
#  [ 337 5736]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87      6073
#            1       0.63      0.30      0.41      1896
#
#     accuracy                           0.79      7969
#    macro avg       0.72      0.62      0.64      7969
# weighted avg       0.77      0.79      0.76      7969

# %%
#plot roc curve 
import matplotlib.pyplot as plt 
# predicted probabilities of class 1 
y_pred_prob_logmodel = log_model.predict_proba(x_val)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_val, y_pred_prob_logmodel)
auc = metrics.roc_auc_score(y_val, y_pred_prob_logmodel)
plt.plot(fpr,tpr,label="LogReg_Model, auc ="+str("{:.3f}".format(auc)))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# Grid Search to get the best parameters

# %%
from sklearn.model_selection import GridSearchCV

grid_params = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': np.logspace(-4,4,20),
    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
    'max_iter': [90,100]
}

gridCV = GridSearchCV(log_model, param_grid=grid_params, verbose=True)
gridCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# ...

# %%
print(gridCV.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-eea4634e5853> in <module>
# ----> 1 print(gridCV.best_params_)
#
# NameError: name 'gridCV' is not defined

# %%
good_log_model = LogisticRegression(C=545.5594781168514, max_iter = 100, penalty='l2', solver = "newton-cg", random_state=101)
good_log_model.fit(x_train,y_train)
y_val_goodlogmodel = good_log_model.predict(x_val)
print("Accuracy:", metrics.accuracy_score(y_val,y_val_goodlogmodel))
print("Recall:", metrics.recall_score(y_val,y_val_goodlogmodel))
print("Precision:", metrics.precision_score(y_val,y_val_goodlogmodel))
print("F1 Score:", metrics.f1_score(y_val,y_val_goodlogmodel))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_val_logmodel,labels=[1,0])
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_val_logmodel))
# Out:
# Accuracy: 0.8234408332287615
# Recall: 0.4319620253164557
# Precision: 0.7127937336814621
# F1 Score: 0.5379310344827587
#
# Confusion Matrix:
#
# [[ 576 1320]
#  [ 337 5736]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87      6073
#            1       0.63      0.30      0.41      1896
#
#     accuracy                           0.79      7969
#    macro avg       0.72      0.62      0.64      7969
# weighted avg       0.77      0.79      0.76      7969
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:202: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn("newton-cg failed to converge. Increase the "

# %%
#plot roc curve 
import matplotlib.pyplot as plt 
# predicted probabilities of class 1 
y_pred_prob_goodlogmodel = good_log_model.predict_proba(x_val)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_val, y_pred_prob_goodlogmodel)
auc = metrics.roc_auc_score(y_val, y_pred_prob_goodlogmodel)
plt.plot(fpr,tpr,label="LogReg_Model, auc ="+str("{:.3f}".format(auc)))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm 

# create svm Classifier with basic linear kernel 
linearSVM = svm.SVC(kernel="linear")

# Train the model 
linearSVM.fit(x_train,y_train)
y_val_linearSVM = linearSVM.predict(x_val)
print("Accuracy:", metrics.accuracy_score(y_val,y_val_linearSVM))
print("Recall:", metrics.recall_score(y_val,y_val_linearSVM))
print("Precision:", metrics.precision_score(y_val,y_val_linearSVM))
print("F1 Score:", metrics.f1_score(y_val,y_val_linearSVM))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_val_linearSVM)
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_val_linearSVM))

# %%
#plot roc curve 
import matplotlib.pyplot as plt 
# predicted probabilities of class 1 
y_pred_prob_linearSVM = linearSVM.predict_proba(x_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_prob_linearSVM)
auc = metrics.roc_auc_score(y_test, y_pred_prob_linearSVM)
plt.plot(fpr,tpr,label="LinearSVM_Model, auc ="+str("{:.3f}".format(auc)))
plt.legend(loc=4)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

grid_params = {
    'gamma': [1,0.1,0.01,0.001]
    'C': [0.1,1, 10, 100],
    'kernel': ['rbf', 'poly', 'sigmoid']
}

gridCV = GridSearchCV(linearSVM, param_grid=grid_params, verbose=True)
gridCV.fit(x_train,y_train)

# %%
print(gridCV.best_params_)

# %%
good_SVM = svm.SVC(C=545.5594781168514, max_iter = 100, penalty='l2', solver = "newton-cg", random_state=101)
good_SVM.fit(x_train,y_train)
y_val_goodSVM = good_SVM.predict(x_val)
print("Accuracy:", metrics.accuracy_score(y_val,y_val_goodSVM))
print("Recall:", metrics.recall_score(y_val,y_val_goodSVM))
print("Precision:", metrics.precision_score(y_val,y_val_goodSVM))
print("F1 Score:", metrics.f1_score(y_val,y_val_goodSVM))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_val_goodSVM,labels=[1,0])
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_val_logmodel))

# %% [markdown]
# # AdaBoost

# %%
# import AdaBoost Model 
from sklearn.ensemble import AdaBoostClassifier 

abModel = AdaBoostClassifier(random_state=23)
abModel.fit(x_train,y_train)
y_pred_abModel = abModel.predict(x_val)

# %%
print("Accuracy:", metrics.accuracy_score(y_val,y_pred_abModel))
print("Recall:", metrics.recall_score(y_val,y_pred_abModel))
print("Precision:", metrics.precision_score(y_val,y_pred_abModel))
print("F1 Score:", metrics.f1_score(y_val,y_pred_abModel))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_pred_abModel)
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_pred_abModel))

# %%
from sklearn.model_selection import GridSearchCV 
grid_params = {
    'n_estimators': [50,100,200,400],
    'algorithm': ['SAMME','SAMME.R'],
    'learning_rate': [0.01,0.05,0.1,0.2],
}

gridCV = GridSearchCV(abModel, param_grid=grid_params, verbose=True)
gridCV.fit(x_train,y_train)
print(gridCV.best_params_)

# %%
good_AB = svm.SVC(C=545.5594781168514, max_iter = 100, penalty='l2', solver = "newton-cg", random_state=101)
good_AB.fit(x_train,y_train)
y_val_goodAB = good_AB.predict(x_val)
print("Accuracy:", metrics.accuracy_score(y_val,y_val_goodAB))
print("Recall:", metrics.recall_score(y_val,y_val_goodAB))
print("Precision:", metrics.precision_score(y_val,y_val_goodAB))
print("F1 Score:", metrics.f1_score(y_val,y_val_goodAB))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_val_goodAB,labels=[1,0])
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_val_goodAB))

# %% [markdown]
# # Gradient Boosting

# %%
# import Gradient Bootsting Model 
from sklearn.ensemble import GradientBoostingClassifier 

gbModel = GradientBoostingClassifier(random_state=23)
gbModel.fit(x_train,y_train)
y_pred_gbModel = gbModel.predict(x_val)

# %%
print("Accuracy:", metrics.accuracy_score(y_val,y_pred_gbModel))
print("Recall:", metrics.recall_score(y_val,y_pred_gbModel))
print("Precision:", metrics.precision_score(y_val,y_pred_gbModel))
print("F1 Score:", metrics.f1_score(y_val,y_pred_gbModel))

# confusion matrix 
cfn_matrix = metrics.confusion_matrix(y_val,y_pred_gbModel)
print("\nConfusion Matrix:\n")
print(cfn_matrix)

# Classification Report 
print("\nClassification Report:\n")

print(classification_report(y_val, y_pred_gbModel))

# %%
from sklearn.model_selection import GridSearchCV 
grid_params = {
    'n_estimators': [50,100,200,400],
    'max_depth': [3,4,5,6,7,8],
    'learning_rate': [0.01,0.05,0.1,0.2],
    'max_leaf_nodes': [2,4,6,8]
}

gridCV = GridSearchCV(GradientBoostingClassifier(), param_grid=grid_params, verbose=True)
gridCV.fit(x_train,y_train)
print(gridCV.best_params_)
